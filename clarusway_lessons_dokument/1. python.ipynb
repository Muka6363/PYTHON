# %%
pip list
# Out:
# Package              Version
# -------------------- -------
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                21.4.0
# backcall             0.2.0
# black                21.12b0
# bleach               4.1.0
# cffi                 1.15.0
# click                8.0.3
# colorama             0.4.4
# debugpy              1.5.1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.3
# executing            0.8.2
# ipykernel            6.7.0
# ipython              8.0.1
# ipython-genutils     0.2.0
# ipywidgets           7.6.5
# jedi                 0.18.1
# Jinja2               3.0.3
# jsonschema           4.4.0
# jupyter              1.0.0
# jupyter-client       7.1.2
# jupyter-console      6.4.0
# jupyter-core         4.9.1
# jupyterlab-pygments  0.1.2
# jupyterlab-widgets   1.0.2
# MarkupSafe           2.0.1
# matplotlib-inline    0.1.3
# mistune              0.8.4
# my-package           0.0.0
# ...

# %%
# bır arabanın km cınsınden gıttıgı mesafenın mıl cınsınden hesaplanması??? mıl = km/1.609344
print("kac kılometre gıttınız??")
mesKM = input()
mesML = float(mesKM) / 1.609344
mesML = round(mesML, 2) # bununla uzayıp gıden degerlerı engelleyıp sadece belırtılen mıktarda (noktadan sonra) yazdırırız
print(str(mesKM) + " km = " + str(mesML) + " mıl.")
# Out:
# kac kılometre gıttınız??
# 63
# 63 km = 39.15 mıl.

# %%
ad = "Mustafa"
soyad = "KAYIKCI"
yas = 34
mekan = "Vatan"
print(f"Benım adım {ad} soyadım {soyad} yasım {yas}. Yerim ise {mekan}dır") # f-strıng metoduyla yazım daha basıtttır.
# Out:
# Benım adım Mustafa soyadım KAYIKCI yasım 34. Yerim ise Vatandır

# %%
# Str-Method	Description
"""
capitalize()	Converts the first character to upper case
casefold()	Converts string into lower case
center()	Returns a centered string
count()	Returns the number of times a specified value occurs in a string
encode()	Returns an encoded version of the string
endswith()	Returns true if the string ends with the specified value
expandtabs()	Sets the tab size of the string
find()	Searches the string for a specified value and returns the position of where it was found
format()	Formats specified values in a string
format_map()	Formats specified values in a string
index()	Searches the string for a specified value and returns the position of where it was found
isalnum()	Returns True if all characters in the string are alphanumeric
isalpha()	Returns True if all characters in the string are in the alphabet
isascii()	Returns True if all characters in the string are ascii characters
isdecimal()	Returns True if all characters in the string are decimals
isdigit()	Returns True if all characters in the string are digits
isidentifier()	Returns True if the string is an identifier
islower()	Returns True if all characters in the string are lower case
isnumeric()	Returns True if all characters in the string are numeric
isprintable()	Returns True if all characters in the string are printable
isspace()	Returns True if all characters in the string are whitespaces
istitle()	Returns True if the string follows the rules of a title
isupper()	Returns True if all characters in the string are upper case
join()	Converts the elements of an iterable into a string
ljust()	Returns a left justified version of the string
lower()	Converts a string into lower case
lstrip()	Returns a left trim version of the string
maketrans()	Returns a translation table to be used in translations
partition()	Returns a tuple where the string is parted into three parts
replace()	Returns a string where a specified value is replaced with a specified value
rfind()	Searches the string for a specified value and returns the last position of where it was found
rindex()	Searches the string for a specified value and returns the last position of where it was found
rjust()	Returns a right justified version of the string
rpartition()	Returns a tuple where the string is parted into three parts
rsplit()	Splits the string at the specified separator, and returns a list
rstrip()	Returns a right trim version of the string
split()	Splits the string at the specified separator, and returns a list
splitlines()	Splits the string at line breaks and returns a list
startswith()	Returns true if the string starts with the specified value
strip()	Returns a trimmed version of the string
swapcase()	Swaps cases, lower case becomes upper case and vice versa
title()	Converts the first character of each word to upper case
translate()	Returns a translated string
upper()	Converts a string into upper case
zfill()	Fills the string with a specified number of 0 values at the beginning """

# %%
w = "Hello world.Burası VATAN63"
x = w.replace("w", "W") # replace ıle denılen elemanın, kendısını, denılen baska bır elemanla degıstırıız. ilkı yazıp ıkınsıne "" boyle hıcbırsey yazmazsak o zaman bu karakterımızı sılerız.
print(x)
xx = w.replace("l", "")
print(xx)
y = w.rstrip("63") # strıp ıle de ya boslukları ya da str"" olarak belıttıgımız sonundakı elemanı sıler
print(y)
yy = w.lstrip("Hello") # strıp ıle de ya boslukları ya da str"" olarak belıttıgımız sonundakı elemanı sıler
print(yy)
yyy = w.strip("eHl36") # strıp ıle de ya boslukları ya da str"" olarak belıttıgımız sonundakı elemanı sıler
print(yyy)
z = w.isdigit() # "UNUTMA" <<<is>>> ile baslayanların hepsınde bı soru sorar. cevap evetse;True hayır ıse :False dıye cıktı verır.dondurur. "isalpha" alfabetık mı dıye sorar
print(z)
k = w.islower() # tum harflerı kucuk mu?? True - False
print(k)
c = w.casefold()
print(c)
m = w.split() # splıt ıle, () ıcıne neyı baz alırsak str ıcını, bu krıterımızı dıkkate alarak boler, ve bunların herbırını str ıcınde olacak sekılde bır lıste yapar
print(m)
n = w.split("o") # splıt ıle, () ıcıne neyı baz alırsak str ıcını, bu krıterımızı dıkkate alarak boler, ve bunların herbırını str ıcınde olacak sekılde bır lıste yapar
print(n)
j = "--".join(w) # join ıle de splıt ın tam tersini yaparız. bırlestırırız. oncesıne yazdıgımız karaktere gore tum elemanlarının arasına yazdırırız."" hepsını yapısıtrır " " hepsının arasına bır bosluk bırakır
print(j)
sonuc = ".".join(w)
print(sonuc)
sonuc = w.index("63")  #  index ıle hangı karakterı yazarsek onun ındex numarasını buluruz
print(sonuc)
sonuc = w.index("A") 
print(sonuc)
sonuc = w[20] 
print(sonuc)
coun = w.count("o") # count ole belırttıgımız karakterın kullanıldıgı mıktarı ogrenırız. bu arayacagımızı bellı bır ındex numarası arasında da arayabılırız.
print(coun)
coun1 = w.count("o", 1,6) # bu arayacagımızı bellı bır ındex numarası arasında da arayabılırız.("karakter", start, stop)
print(coun1)  
end = w.endswith("3")
print(end)
fın = w.find("VA")
print(fın) #  fınd ıle bır karakterın olup olmadıgını sorgular ve eger varsa bulundugu, basladıgı, ındex numarasını dondururuz
fın = w.find("j")
print(fın) #  fınd ıle bır bulunmayan bısey aratırsak sonuc -1 verır.
# Out:
# Hello World.Burası VATAN63
# Heo word.Burası VATAN63
# Hello world.Burası VATAN
#  world.Burası VATAN63
# o world.Burası VATAN
# False
# False
# hello world.burası vatan63
# ['Hello', 'world.Burası', 'VATAN63']
# ['Hell', ' w', 'rld.Burası VATAN63']
# H--e--l--l--o-- --w--o--r--l--d--.--B--u--r--a--s--ı-- --V--A--T--A--N--6--3
# H.e.l.l.o. .w.o.r.l.d...B.u.r.a.s.ı. .V.A.T.A.N.6.3
# 24
# 20
# A
# 2
# 1
# True
# -1

# %%
# LİSTELER
""" Liste veri türünün birkaç yöntemi daha vardır. Liste nesnelerinin tüm yöntemleri şunlardır:
list.append( x )
Listenin sonuna bir öğe ekleyin.
list.extend( yinelenebilir )
Yinelenebilirdeki tüm öğeleri ekleyerek listeyi genişletin.
list.insert( ben , x )
Belirli bir konuma bir öğe ekleyin. İlk argüman, önüne eklenecek öğenin indeksidir, bu nedenle listenin önüne eklenir ve eşdeğerdir .a.insert(0, x)a.insert(len(a), x)a.append(x)
list.remove( x )
Değeri x'e eşit olan ilk öğeyi listeden kaldırın . ValueErrorBöyle bir öğe yoksa bir yükseltir .
list.pop( [ ben ] )
Listede verilen konumdaki öğeyi kaldırın ve iade edin. Dizin belirtilmemişse, a.pop()listedeki son öğeyi kaldırır ve döndürür. (Yöntem imzasındaki i'nin etrafındaki köşeli parantezler , parametrenin isteğe bağlı olduğunu, bu konumda köşeli parantez yazmanız gerektiğini değil. Bu gösterimi Python Kitaplığı Referansında sık sık göreceksiniz.)
list.clear( )
Tüm öğeleri listeden kaldırın. ile eşdeğerdir .del a[:]
list.index( x [ , başla [ , bitir ] ] )
Değeri x'e eşit olan ilk öğe listesinde sıfır tabanlı dizin döndürün . ValueErrorBöyle bir öğe yoksa a'yı yükseltir .
İsteğe bağlı başlangıç ​​ve bitiş argümanları dilim notasyonunda olduğu gibi yorumlanır ve aramayı listenin belirli bir alt dizisiyle sınırlamak için kullanılır. Döndürülen dizin, başlangıç ​​bağımsız değişkeni yerine tam dizinin başlangıcına göre hesaplanır .
list.count( x )
Listede x'in kaç kez göründüğünü döndürün.
list.sort( * , anahtar = Yok , ters = Yanlış )
Listenin öğelerini yerinde sıralayın (argümanlar, sıralama özelleştirmesi için kullanılabilir sorted(), açıklamalarına bakın).
list.reverse( )
Listenin öğelerini yerinde tersine çevirin.
list.copy( )
Listenin sığ bir kopyasını döndürün. ile eşdeğerdir a[:].
"""

# %%
lıste = [1, 2, 3, 4, 5, 6, 7, 8, 5, 5, 9]
lıste[5] = "dort"
#EKLEME
print(lıste)
lıste.append("a")
print(lıste)
lıste.insert(2, 88) # belırtılen ındex numarasına yenı bır deger atarız
print(lıste)
#SILME
lıste.pop() # ındex numrası belırtılmemısse lıstenın en sonundakı elemanını sıler
print(lıste)

lıste.pop(-2) # ındex numrası belırtılmemısse lıstenın en sonundakı elemanını sıler
print(lıste)
lıste.remove("dort") # remove ıse elemanın dırekt kendısını yazarak sılebılırız. (ındex numrası degıl)
print(lıste)
# SIRALAMA
lıste.sort() # alfabetık olarak sılama yapar. kucukten buyuge dogru
print(lıste)
lıste.reverse() # tersten alfabetık olarak sılama yapar.  buyukten kucuge dogru
print(lıste) 
 
print(lıste.count(5)) # belırtılen elemanın kac kez kullanıldıgını sorgular
print(lıste.index(5)) # belırtılen ındextekı elemanı sorgular

lıste.clear() # bununla lıstemızın ıcını temızlıyoruz. bos bır lıste halıne getırıyor
# Out:
# [1, 2, 3, 4, 5, 'dort', 7, 8, 5, 5, 9]
# [1, 2, 3, 4, 5, 'dort', 7, 8, 5, 5, 9, 'a']
# [1, 2, 88, 3, 4, 5, 'dort', 7, 8, 5, 5, 9, 'a']
# [1, 2, 88, 3, 4, 5, 'dort', 7, 8, 5, 5, 9]
# [1, 2, 88, 3, 4, 5, 'dort', 7, 8, 5, 9]
# [1, 2, 88, 3, 4, 5, 7, 8, 5, 9]
# [1, 2, 3, 4, 5, 5, 7, 8, 9, 88]
# [88, 9, 8, 7, 5, 5, 4, 3, 2, 1]
# 2
# 4
# []

# %%
ısımler = ["ada", "yıgıt", "hasan", "berıl"]
yaslar = [1998, 1997, 2000, 1987]
yaslar.sort()
print(yaslar)
yaslar.reverse()
print(yaslar)
x = min(yaslar)
print(x)
y = max(yaslar)
print(y)
ww = "hasan" in ısımler # belırtılen elemanın bu lıstede olup olmadıgı sorulu. True-False cevap alırız...
print(ww)
sss = "samsung 1, samsung 2,samsung 3" # bu strıngı bır lısteye cevırınız???
lıstm = sss.split(",")
print(lıstm)
# soru: kullanıcıdan alınacak 3 tane markayı bır lıste ıcıne yazınız???
markalar = []
marka = input("marka gırınız: ")
markalar.append(marka) 

marka = input("marka gırınız: ")
markalar.append(marka)

marka = input("marka gırınız: ")
markalar.append(marka)

print(markalar)
# Out:
# [1987, 1997, 1998, 2000]
# [2000, 1998, 1997, 1987]
# 1987
# 2000
# True
# ['samsung 1', ' samsung 2', 'samsung 3']
# marka gırınız: retyu
# marka gırınız: aergsdr
# marka gırınız: hsderthd
# ['retyu', 'aergsdr', 'hsderthd']

# %%
# TUPLE
# Tuple lar da aynı lısteler gıbı colletıonlardandır. 
# ancak lıstelerde uygulanan metaodlar Tublelarda uygulayamıyoruz.
# Tuplelarda sadece "ındex" ve "count" kullanabılıyoruz.
tup = (1, 3, 5)
tup = 1, 3, 5 # seklınde de yazılır. kendılıgınde parantez var sayılır

# %%
# DICTIONARY

# %%
opel = {"ad" : "opel",
             "modx" : "corsa", 
             "yıl": 2020}
opel["ad"] = "4ceker"
print(opel)
# Out:
# {'ad': '4ceker', 'modx': 'corsa', 'yıl': 2020}

# %%
# 3 urunun 3 ayrı bılgısını (id, ad, fıyat) bır dıct. ıcıne yazınız

urunler = {}
id = int(input("urun id: "))
ad = input("urun adı: ")
fıyat = float(input("urun fıyatı: "))
urunler[id] = {
    "ad" : ad,
    
    "fıyat" : fıyat
}
urunler = {}
id = int(input("urun id: "))
ad = input("urun adı: ")
fıyat = float(input("urun fıyatı: "))
urunler[id] = {
    "ad" : ad,
    "fıyat" : fıyat
}
urunler = {}
id = int(input("urun id: "))
ad = input("urun adı: ")
fıyat = float(input("urun fıyatı: "))
urunler[id] = {
    "ad" : ad,
    "fıyat" : fıyat
}
print(urunler)
# Out:
# urun id: 1
# urun adı: q
# urun fıyatı: 1
# urun id: 2
# urun adı: w
# urun fıyatı: 3
# urun id: 4
# urun adı: re
# urun fıyatı: 5
# {4: {'ad': 're', 'fıyat': 5.0}}
